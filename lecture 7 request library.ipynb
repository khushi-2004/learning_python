# %% [markdown]
#     system ---> wifi ----> ip

# %% [markdown]
#     human(client) ---> browser ---> youtube ---> server ----> search in DNS ----> response
#                               ---------request-----------
#                                      (get request)

# %%
import requests

# %%
print(dir(requests))
# Out:
# ['ConnectTimeout', 'ConnectionError', 'DependencyWarning', 'FileModeWarning', 'HTTPError', 'JSONDecodeError', 'NullHandler', 'PreparedRequest', 'ReadTimeout', 'Request', 'RequestException', 'RequestsDependencyWarning', 'Response', 'Session', 'Timeout', 'TooManyRedirects', 'URLRequired', '__author__', '__author_email__', '__build__', '__builtins__', '__cached__', '__cake__', '__copyright__', '__description__', '__doc__', '__file__', '__license__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__title__', '__url__', '__version__', '_check_cryptography', '_internal_utils', 'adapters', 'api', 'auth', 'certs', 'chardet_version', 'charset_normalizer_version', 'check_compatibility', 'codes', 'compat', 'cookies', 'delete', 'exceptions', 'get', 'head', 'hooks', 'logging', 'models', 'options', 'packages', 'patch', 'post', 'put', 'request', 'session', 'sessions', 'ssl', 'status_codes', 'structures', 'urllib3', 'utils', 'warnings']

# %% [markdown]
# browser ----> request to use----> services

# %% [markdown]
#         type of response:
#
#                 1. information response (100-199)
#
#                 2. successful response (200-299)
#
#                 3. redirect     (300-399)
#
#                 4. client error (400-499)
#
#                 5. server error  (500-599)

# %%
url='https://www.google.com/search?q=stack+overflow&oq=stack+over&gs_lcrp=EgZjaHJvbWUqBwgBEAAYjwIyBggAEEUYOTIHCAEQABiPAtIBCDk5MjJqMGo3qAIAsAIA&sourceid=chrome&ie=UTF-8'

# %%
resp=requests.get(url)

# %%
resp.reason
# Out:
# 'OK'

# %%
resp.content
# Out:
# b'<!doctype html><html lang="en-IN"><head><meta charset="UTF-8"><meta content="AuGja1tZnula8g99g84tXdYpnTOYY3dZDWwPGrQlieoc5O2XUK43BBV9fkFZ+xa73I8tnEUcdTsA+qiYLKtuggkAAABxeyJvcmlnaW4iOiJodHRwczovL2dvb2dsZS5jby5pbjo0NDMiLCJmZWF0dXJlIjoiTG9uZ0FuaW1hdGlvbkZyYW1lVGltaW5nIiwiZXhwaXJ5IjoxNzA5NjgzMTk5LCJpc1N1YmRvbWFpbiI6dHJ1ZX0=" http-equiv="origin-trial"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>stack overflow - Google Search</title><script nonce="l4ulcNJo0BxQiuZP5ZsjxQ">(function(){\ndocument.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"===c||"q"===c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!==document.documentElement;a=a.parentElement)if("A"===a.tagName){a="1"===a.getAttribute("data-nohref");break a}a=!1}a&&b.preventDefaul
# ...

# %%
url1='https://images.pexels.com/photos/674010/pexels-photo-674010.jpeg?auto=compress&cs=tinysrgb&w=600'

# %%
import requests

# %%
resp1=requests.get(url1)

# %%
resp1.reason
# Out:
# 'OK'

# %%
resp1.headers
# Out:
# {'Date': 'Thu, 25 Jan 2024 08:58:44 GMT', 'Content-Type': 'image/jpeg', 'Content-Length': '61255', 'Connection': 'keep-alive', 'Access-Control-Allow-Origin': '*', 'Cf-Bgj': 'imgq:85,h2pri', 'Cf-Polished': 'status=not_needed', 'Cross-Origin-Resource-Policy': 'cross-origin', 'Timing-Allow-Origin': '*', 'X-Cache': 'HIT, HIT', 'X-Content-Type-Options': 'nosniff', 'X-Imgix-Render-Farm': '01.140360', 'X-Served-By': 'cache-sjc10067-SJC, cache-bma1658-BMA', 'cache-control': 'public, max-age=31536000', 'last-modified': 'Sat, 21 Oct 2023 12:41:48 GMT', 'x-imgix-id': '172b3826a6ed49369fbbced7994ebe4afaf519ff', 'CF-Cache-Status': 'HIT', 'Age': '5989443', 'Expires': 'Fri, 24 Jan 2025 08:58:44 GMT', 'Accept-Ranges': 'bytes', 'Set-Cookie': '__cf_bm=UA217VLSQKF8vMOJ4yV2QxuirgbVIuNrkk.6WvaVuC0-1706173124-1-AWs6fLg9gvoIXAqawQOW7rPTUnhc2twvoQq84q+rXKkQB6sINT1r9jymMVu7+ucox+CEjrBGBZkdthmT9NjzxOg=; path=/; expires=Thu, 25-Jan-24 09:28:44 GMT; domain=.pexels.com; HttpOnly; Secure; SameSite=None', 'Vary': 
# ...

# %%
print(resp1.content)
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00H\x00H\x00\x00\xff\xe2\x02\x1cICC_PROFILE\x00\x01\x01\x00\x00\x02\x0clcms\x02\x10\x00\x00mntrRGB XYZ \x07\xdc\x00\x01\x00\x19\x00\x03\x00)\x009acspAPPL\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xf6\xd6\x00\x01\x00\x00\x00\x00\xd3-lcms\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\ndesc\x00\x00\x00\xfc\x00\x00\x00^cprt\x00\x00\x01\\\x00\x00\x00\x0bwtpt\x00\x00\x01h\x00\x00\x00\x14bkpt\x00\x00\x01|\x00\x00\x00\x14rXYZ\x00\x00\x01\x90\x00\x00\x00\x14gXYZ\x00\x00\x01\xa4\x00\x00\x00\x14bXYZ\x00\x00\x01\xb8\x00\x00\x00\x14rTRC\x00\x00\x01\xcc\x00\x00\x00@gTRC\x00\x00\x01\xcc\x00\x00\x00@bTRC\x00\x00\x01\xcc\x00\x00\x00@desc\x00\x00\x00\x00\x00\x00\x00\x03c2\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00
# ...

# %% [markdown]
# # requests:
#                 to make http request

# %%
import requests

# %%
url='https://www.geeksforgeeks.org/courses?source=google&medium=cpc&device=c&keyword=geeksforgeeks&matchtype=e&campaignid=20039445781&adgroup=147845288105&gad_source=1&gclid=Cj0KCQiAh8OtBhCQARIsAIkWb68QAlYcGKDYcrGvdrnTHE-KuT2xwPJawHDMYc8gq0fh-PrUfXA2powaAnI9EALw_wcB'

# %%
res=requests.get(url)

# %%
res.reason
# Out:
# 'OK'

# %%
res.headers
# Out:
# {'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Server': 'nginx/1.10.3', 'Date': 'Thu, 25 Jan 2024 08:35:50 GMT', 'X-Frame-Options': 'DENY', 'Referrer-Policy': 'origin-when-cross-origin', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '1; mode=block', 'Cache-Control': 's-maxage=600, max-age=0', 'X-Powered-By': 'Next.js', 'Content-Encoding': 'gzip', 'Vary': 'Accept-Encoding', 'X-Cache': 'Hit from cloudfront', 'Via': '1.1 b793f65e5e9098bee433f16b039d6bea.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'PNQ50-P2', 'X-Amz-Cf-Id': 'Hye6FUoyrF3FHeO9q3NOIGK_isaflICaOXXwNlUQJi37pW7XF1ua1g==', 'Age': '34'}

# %%
print(res)
# Out:
# <Response [200]>

# %%
print(res.content)
# Out:
# b'<!DOCTYPE html><html lang="en"><head><link rel="icon" href="https://media.geeksforgeeks.org/wp-content/cdn-uploads/gfg_favicon.png" type="image/x-icon"/><meta http-equiv="Content-type" content="text/html;charset=UTF-8"/><meta charSet="UTF-8"/><meta name="keywords" content="programming, coding, online, code online, online judge, practice, run code, test, expected outcome, programming competition, programming contest, online programming, online computer programming"/><meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1"/><title>Courses GeeksforGeeks | Interactive LIVE and Self-Paced Courses</title><meta name="description" content="Platform to practice programming problems. Solve company interview questions and improve your coding intellect"/><meta property="og:title" content="Courses GeeksforGeeks | Interactive LIVE and Self-Paced Courses"/><meta property="og:description" content="Platform to practice programming problems. Solve company interview questi
# ...

# %%
url='https://webhook.site/df2a618a-55a8-413b-8a6d-4ab5296e7876'

# %%
data={
    'name':'ram',
    'age':90,
    'address':'jaipur'
}

# %%
requests.post(url,data=data)
# Out:
# <Response [200]>

# %%
requests.post(url,json=data)
# Out:
# <Response [200]>

# %% [markdown]
#         list & tuple ---> data and json form

# %% [markdown]
# # API: Application programming interface

# %%
url1='https://images.pexels.com/photos/674010/pexels-photo-674010.jpeg?auto=compress&cs=tinysrgb&w=600'

# %%
res1=requests.get(url)

# %%
data=resp1.content

# %%
data
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00H\x00H\x00\x00\xff\xe2\x02\x1cICC_PROFILE\x00\x01\x01\x00\x00\x02\x0clcms\x02\x10\x00\x00mntrRGB XYZ \x07\xdc\x00\x01\x00\x19\x00\x03\x00)\x009acspAPPL\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xf6\xd6\x00\x01\x00\x00\x00\x00\xd3-lcms\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\ndesc\x00\x00\x00\xfc\x00\x00\x00^cprt\x00\x00\x01\\\x00\x00\x00\x0bwtpt\x00\x00\x01h\x00\x00\x00\x14bkpt\x00\x00\x01|\x00\x00\x00\x14rXYZ\x00\x00\x01\x90\x00\x00\x00\x14gXYZ\x00\x00\x01\xa4\x00\x00\x00\x14bXYZ\x00\x00\x01\xb8\x00\x00\x00\x14rTRC\x00\x00\x01\xcc\x00\x00\x00@gTRC\x00\x00\x01\xcc\x00\x00\x00@bTRC\x00\x00\x01\xcc\x00\x00\x00@desc\x00\x00\x00\x00\x00\x00\x00\x03c2\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00
# ...

# %%
with open('img1.jpeg','wb') as f:
    f.write(data)

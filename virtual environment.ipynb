# %% [markdown]
#     setp to create virtual environment in jupyter notebook:
#
#         deactivate the base environment
#                 conda deactivate
#
#         step 1: create a virtual environment
#                 python -m venv name
#
#         step 2: activate the virtual environment
#                 venv\Sripts\activate
#
#         step 3: Install jupyter kernel for the virtual enviromnemt using the following command:
#                 ipython kernel install --user --name=name
#
#         step 4: select the installed kernel when you want to use jupyter notebook in this virtual environment
#
#         step 5: jupyter -kernelspec unstall venv  (unstalling jupyter kernel that we have install in current environment

# %%
pip install pyppeteer
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install --upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip list --outdated
# Out:
# Package                       Version      Latest     Type
# ----------------------------- ------------ ---------- -----
# aiobotocore                   2.5.0        2.11.2     wheel
# aiofiles                      22.1.0       23.2.1     wheel
# aiohttp                       3.8.5        3.9.3      wheel
# aioitertools                  0.7.1        0.11.0     wheel
# aiosignal                     1.2.0        1.3.1      wheel
# aiosqlite                     0.18.0       0.19.0     wheel
# alabaster                     0.7.12       0.7.16     wheel
# anaconda-cloud-auth           0.1.3        0.4.1      wheel
# anyio                         3.5.0        4.2.0      wheel
# argon2-cffi                   21.3.0       23.1.0     wheel
# arrow                         1.2.3        1.3.0      wheel
# astroid                       2.14.2       3.0.3      wheel
# astropy                       5.1          6.0.0      wheel
# asttokens                     2.0.5        2.4.1      wheel
# ...

# %%
pip install pyppeteer
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyppeteer
